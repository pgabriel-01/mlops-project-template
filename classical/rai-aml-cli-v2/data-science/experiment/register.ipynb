# %%
import argparse
from pathlib import Path
import pickle
import mlflow

import os 
import json

# %%
# Define Arguments for this step

class MyArgs:
    def __init__(self, /, **kwargs):
        self.__dict__.update(kwargs)

args = MyArgs(
                model_name = "taxi-model",
                model_path = "/tmp/train",
                evaluation_output = "/tmp/evaluate", 
                model_info_output_path = "/tmp/model_info_output_path"
                )

# %%
def main(args):
    '''Loads model, registers it if deply flag is True'''
    
    with open((Path(args.evaluation_output) / "deploy_flag"), 'rb') as infile:
        deploy_flag = int(infile.read())

    mlflow.log_metric("deploy flag", int(deploy_flag))
    
    if deploy_flag==1:

        print("Registering ", args.model_name)

        # load model
        model =  mlflow.sklearn.load_model(args.model_path) 

        # log model using mlflow
        mlflow.sklearn.log_model(model, args.model_name)

        # register logged model using mlflow
        run_id = mlflow.active_run().info.run_id
        model_uri = f'runs:/{run_id}/{args.model_name}'
        mlflow_model = mlflow.register_model(model_uri, args.model_name)
        model_version = mlflow_model.version

        # write model info
        print("Writing JSON")
        dict = {"id": "{0}:{1}".format(args.model_name, model_version)}
        output_path = os.path.join(args.model_info_output_path, "model_info.json")
        with open(output_path, "w") as of:
            json.dump(dict, fp=of)

    else:
        print("Model will not be registered!")

# %%
mlflow.start_run()

lines = [
    f"Model name: {args.model_name}",
    f"Model path: {args.model_path}",
    f"Evaluation output path: {args.evaluation_output}",
]

for line in lines:
    print(line)

main(args)

mlflow.end_run()
# Out:
# 2026/01/21 13:33:52 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/21 13:33:52 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/21 13:33:52 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/21 13:33:52 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/21 13:33:52 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/21 13:33:52 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# Model name: taxi-model
# Model path: /tmp/train
# Evaluation output path: /tmp/evaluate
# Registering  taxi-model
# 2026/01/21 13:33:54 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/01/21 13:34:02 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/21 13:34:02 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/21 13:34:02 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/21 13:34:02 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# Successfully registered model 'taxi-model'.
# 2026/01/21 13:34:03 WARNING mlflow.tracking._model_registry.fluent: Run with id 926bae818bbb4ba89e23b660f2742e27 has no artifacts at artifact path 'taxi-model', registering model based on models:/m-5ee907a14ead4c73949b3a07d5d0b584 instead
# Writing JSON
# Created version '1' of model 'taxi-model'.
